# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmafatimah/2025-2026-even--AI-B-DS-Asma-Fatimah_4070-/blob/main/Week5_10_03_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#z-score
import numpy as np
data = [10,20,30,40,50]
mean = np.mean(data)
print("Mean", mean)
std_dev=np.std(data, ddof= 1)
print("Standard deviation", std_dev)
x_mean = 40
z_score = (x_mean)/std_dev
print("Z-score of 40", z_score)
z_score = [(x_mean/std_dev for x in data)]
print("Z-score of data", z_score)
# Out:
# Mean 30.0
# Standard deviation 15.811388300841896
# Z-score of 40 2.5298221281347035
# Z-score of data [<generator object <genexpr> at 0x7d7a7e898110>]

# %%
#Statistical Interface
import numpy as np
import math
population = np.array([10,20,30,40,50,60,70])
N = len(population)
print("population size:",N)
mu=np.mean(population)
print("population mean :",mu)
sigma2 = np.var(population,ddof = 0)
print("population variance :",sigma2)
sigma = np.sqrt(sigma2)
print("population standard deviation:",sigma)
sample = np.array([20,30,40,50])
n = len(sample)
print("\n sample size:",n)
x_bar_mu = np.mean(sample)
print("sample mean:",x_bar)
s2=np.var(sample,ddof = 1)
print("sample variance:",s2)
s=np.sqrt(s2)
print("sample standard deviation:",s)
SE = sigma/math.sqrt(n)
print("\n standard error:",SE)
z_score=(x_bar_mu)/SE
print("\n z_score:",z_score)
# Out:
# population size: 7
# population mean : 40.0
# population variance : 400.0
# population standard deviation: 20.0
#
#  sample size: 4
# sample mean: 35.0
# sample variance: 166.66666666666666
# sample standard deviation: 12.909944487358056
#
#  standard error: 10.0
#
#  z_score: 3.5
